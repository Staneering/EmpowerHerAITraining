# %% [markdown]
# # **Introduction to Python**
# *(Jupyter Notebook - `.ipynb`)*
#
# ---
#
# ## **What is Python?**
# Python is a **high-level**, **interpreted**, and **general-purpose** programming language known for:
# - **Simple syntax** (easy to read and write).
# - **Versatility** (used in web dev, data science, automation, AI, and more).
# - **Large community & libraries** (e.g., NumPy, Pandas, Django).
#
# > *"Python is the second-best language for everything."* — *Anonymous*
#
# ---
#
# ## **Fundamental Concepts**
#
# ### **1. Variables & Data Types**
# ```python
# name = "Alice"      # String (text)
# age = 25           # Integer (whole number)
# height = 5.9       # Float (decimal)
# is_student = True  # Boolean (True/False)
# ```
#
# ### **2. Basic Operations**
# ```python
# # Math
# sum = 3 + 2    # 5
# product = 3 * 2  # 6
#
# # String concatenation
# greeting = "Hello, " + name  # "Hello, Alice"
# ```
#
# ### **3. Control Flow**
# - **Conditionals (`if-else`)**
#   ```python
#   if age >= 18:
#       print("Adult")
#   else:
#       print("Minor")
#   ```
# - **Loops (`for`, `while`)**
#   ```python
#   for i in range(3):  # Prints 0, 1, 2
#       print(i)
#   ```
#
# ### **4. Functions**
# ```python
# def greet(name):
#     return f"Hello, {name}!"
#
# print(greet("Bob"))  # "Hello, Bob!"
# ```
#
# ### **5. Lists & Dictionaries**
# ```python
# fruits = ["apple", "banana", "cherry"]  # List (ordered)
# person = {"name": "Alice", "age": 25}   # Dictionary (key-value pairs)
# ```
#
# ---
#
# ## **Why Learn Python?**
# ✅ **Beginner-friendly** (reads like English).
# ✅ **Huge job demand** (used in FAANG, startups, research).
# ✅ **Rich ecosystem** (libraries for almost any task).
#
# ---
#
# ## **Resources to Learn Python**
#
# ### **📚 Books**
# 1. **[Learning Python (PDF)](https://cfm.ehu.es/ricardo/docs/python/Learning_Python.pdf)** – Comprehensive guide.
# 2. **[Best Python Books](https://365datascience.com/tutorials/python-tutorials/best-python-books/)** – Curated list for all levels.
#
# ### **💻 GitHub Repos**
# 1. **[100 Days of Code](https://github.com/Staneering/100-days-of-code-youtube)** – Daily Python challenges.
# 2. **[10 Repos to Master Python](https://medium.com/@parvezshah.shaik/10-github-repositories-to-master-python-c3583645d3b4)** – Projects & tutorials.
#
# ### **🎥 Interactive Learning**
# - **[Python Official Docs](https://docs.python.org/3/tutorial/)**
# - **[W3Schools Python](https://www.w3schools.com/python/)**
#
# ---
#
#
# Happy coding! 🐍
